# %%
#Passo1:Importar bibliotecas
import requests
from bs4 import BeautifulSoup
import pandas as pd 
import time
import urllib.parse
import json
from concurrent.futures import ThreadPoolExecutor, as_completed
import random

# --- PASSO 2: Definir a URL e fazer a requisição inicial ---
url = "https://www.drogariaveracruz.com.br/medicamentos/"
url_base = url

# Header para evitar bloqueio
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# Criar sessão para reaproveitar conexões
session = requests.Session()
session.headers.update(headers)

# --- Funções auxiliares ---

def achar_nome(div):
    tag_h2 = div.find('h2', class_='title')
    if tag_h2:
        tag_a = tag_h2.find('a')
        if tag_a:
            return tag_a.get_text(strip=True)
    return "Nome não encontrado"

def achar_preco(div):
    tag_preco = div.find('p', class_="unit-price p-0")
    if tag_preco:
        return tag_preco.get_text().strip()
    return None

def achar_precopix(div):
    tag_precopix = div.find('p', class_="sale-price-pix")
    if tag_precopix:
        strong_tag = tag_precopix.find('strong')
        if strong_tag:
            return strong_tag.get_text().strip()
    return None 

def achar_total_paginas(soup_inicial):
    container_template = soup_inicial.find('div', class_='page-template')
    if container_template:
        divs_candidatas = container_template.find_all('div', class_='text-center pt-3')
        for div in divs_candidatas:
            texto = div.get_text(strip=True)
            if "Página" in texto:
                partes = texto.split()
                ultima_palavra = partes[-1]
                if ultima_palavra.isdigit():
                    return int(ultima_palavra)
    return 1

def achar_link(produto_html, url_base):
    tag_h2 = produto_html.find('h2', class_='title')
    if tag_h2:
        tag_a = tag_h2.find('a')
        if tag_a and 'href' in tag_a.attrs:
            link_relativo = tag_a.get('href')
            return urllib.parse.urljoin(url_base, link_relativo)
    return "Não encontrado"

def achar_precodesconto(produto_html):
    tag_venda = produto_html.find('p', class_="sale-price p-0")
    if tag_venda:
        strong_tag = tag_venda.find('strong')
        if strong_tag:
            return strong_tag.get_text(strip=True)
    return None

def extrair_detalhes_do_json(soup_detalhes):
    brand = "Não encontrada"
    code = "Não encontrado"
    script_tag = soup_detalhes.find('script', type='application/ld+json')
    if script_tag:
        try:
            raw_json = script_tag.string.strip()
            raw_json = raw_json.replace("\n", "").replace("\r", "").replace("\t", "")
            dados_json = json.loads(raw_json)
            if isinstance(dados_json, list):
                for item in dados_json:
                    if isinstance(item, dict) and 'brand' in item:
                        dados_json = item
                        break
            if 'brand' in dados_json and isinstance(dados_json['brand'], dict):
                brand = dados_json['brand'].get('name', "Não encontrada")
            code = dados_json.get('gtin13', "Não encontrado")
        except Exception as e:
            print("  -> Aviso: Erro ao ler JSON-LD:", e)
    return brand, code

def limpar_preco(preco_str):
    if not preco_str: return None
    try:
        return float(preco_str.replace("R$", "").strip().replace('.', '').replace(',', '.'))
    except (ValueError, TypeError):
        return None

# --- NOVO: baixar página com retry ---
def baixar_url(url, tentativas=3):
    for i in range(tentativas):
        try:
            r = session.get(url, timeout=20)
            if r.status_code == 200:
                return r
        except Exception:
            time.sleep(random.uniform(0.5, 2))
    return None

# --- Função para processar um produto ---
def processar_produto(produto, url_base):
    nome = achar_nome(produto)
    preco = achar_preco(produto)
    precopix = achar_precopix(produto)
    precodesconto = achar_precodesconto(produto)
    link_produto = achar_link(produto, url_base)

    brand, code = None, None
    if link_produto != "Não encontrado":
        responseprodutos = baixar_url(link_produto)
        if responseprodutos:
            soup_produto = BeautifulSoup(responseprodutos.content, 'html.parser')
            brand, code = extrair_detalhes_do_json(soup_produto)

    unit_price = limpar_preco(preco)
    discount_price = limpar_preco(precodesconto)
    pix_price = limpar_preco(precopix)

    discount = round(unit_price - discount_price, 2) if unit_price and discount_price else None
    pix_discount = round(unit_price - pix_price, 2) if unit_price and pix_price else None

    return {
        'Marca': brand,
        'GTIN': code,
        'Desconto': discount,
        'Preco com desconto': discount_price,
        'link': link_produto,
        'Nome': nome,
        'Desconto com pix': pix_discount,
        'Preco pix': pix_price,
        'Preco unitario': unit_price
    }

# --- PRIMEIRA PÁGINA para descobrir total ---
response = baixar_url(url)
soup = BeautifulSoup(response.content, 'html.parser')
total_paginas = achar_total_paginas(soup)

lista_de_produtos = []

# --- LOOP PRINCIPAL ---
for pagina in range(1, total_paginas + 1):
    url_pagina = f'https://www.drogariaveracruz.com.br/medicamentos/?p={pagina}'
    response = baixar_url(url_pagina)
    if not response:
        continue

    soup = BeautifulSoup(response.content, 'html.parser')
    div_produtos = soup.find_all('div', class_='li')

    # processa os produtos em paralelo
    with ThreadPoolExecutor(max_workers=8) as executor:
        futures = [executor.submit(processar_produto, produto, url_base) for produto in div_produtos]
        for future in as_completed(futures):
            resultado = future.result()
            if resultado:
                lista_de_produtos.append(resultado)
                print(f"Extraído: {resultado['Nome']}")

    time.sleep(1)  # pequena pausa entre páginas

# --- FINAL ---
print("\nExtração concluída! Gerando tabela...")
df = pd.DataFrame(lista_de_produtos)
display(df)
# Out:
# Extraído: Blephagel 40g
# Extraído: Materna Nestlé 30 comprimidos revestidos
# Extraído: Lactosil Flora 30 cápsulas
# Extraído: Glifage XR 500mg 30 comprimidos de liberação prolongada
# Extraído: Rivaroxabana 20mg EMS 30 comprimidos revestidos
# Extraído: Slinda 4mg 3 blísteres com 28 comprimidos revestidos cada
# Extraído: Renu Fresh Solução Multiuso 355ml + 120ml + Estojo para Lentes
# Extraído: Niquitin 21mg 7 adesivos transdérmicos transparentes
# Extraído: Probid 30 cápsulas
# Extraído: Calcitran Triflex 30 comprimidos
# Extraído: Aradois 50mg 30 comprimidos revestidos
# Extraído: Salicetil Infantil 100mg 10 comprimidos
# Extraído: Teste de Gravidez Confira 1un
# Extraído: Opti-Free Puremoist 300ml + 120ml + Estojo de Lentes
# Extraído: Ofolato 90 comprimidos
# Extraído: Corus 50mg 30 comprimidos revestidos
# Extraído: VagiSoft 30g + 10 Aplicadores Descartáveis
# Extraído: Neosaldina Solução Oral 15ml
# Extraído: Previgrip Glóbulos Weleda 20g
# Extraído: Niquitin 7mg 7 adesivos transdérmicos transparentes
# Extraído: Previgrip Weleda 50ml
# Extraído: Cafiaspirina 4 comprimidos
# Extraído: Niquitin 14mg 7 adesivos transdérmicos transparentes
# Extraído: Lactosil 10.000 FCC 30 Comprimidos
# Extraído: Coltrax 2mg/ml 3 ampolas com 2ml
# Extraído: Loratadina 10mg Cimed 12 comprimidos
# Extraído: Vitamina D3 2.000UI Althaia 30 cápsulas gel
# Extraído: Digeliv 400GaIU 30 sachês com 2g cada
# Extraído: Sinudoron Weleda 80 comprimidos
# Extraído: Suplemento Alimentar Ofolato D Fer 2000UI 30 comprimidos
# Extraído: Jardiance 25mg 30 comprimidos revestidos
# Extraído: Nitrato de Prata Bastão 90,0% Ifal 0,8g
# Extraído: Neosoro 0,5mg/ml 30ml
# Extraído: Infludoron Glóbulos Weleda 20g
# Extraído: Glargilin 100ui/ml 1 caneta descartável preenchida com 3ml de solução injetável
# Extraído: Arnica Weleda 80 comprimidos
# Extraído: Indux 50mg 10 comprimidos
# Extraído: Citoneurin 5.000 90 comprimidos revestidos
# Extraído: Dimetigass Gotas 75mg 15ml
# Extraído: Forxiga 10mg 30 comprimidos revestidos
# Extraído: Caltrate Ca 600mg + D3 200 UI 60 comprimidos revestidos
# Extraído: Minel 200mg 30 comprimidos revestidos
# Extraído: Naturetti 16 cápsulas
# Extraído: Doss 15.000UI 04 cápsulas gelatinosas moles
# Extraído: Ellura 200mg 30 cápsulas
# Extraído: Diad 1,5mg 1 comprimido
# Extraído: Femibion 1 28 comprimidos
# Extraído: Puran T4 50mcg 30 comprimidos
# Extraído: Contractubex Gel 20g
# Extraído: Plenance EZE 5mg+10mg 30 Cápsulas
# Extraído: Atensina 0,100mg 30 comprimidos
# Extraído: Ginkgo Biloba Catarinense 80mg 30 comprimidos
# Extraído: Supositório de Glicerina Granado Adulto 12un
# Extraído: Cimegripe 20 cápsulas
# Extraído: Sal de Frutas Eno Tradicional 2 envelopes com 5g
#   -> Aviso: Erro ao ler JSON-LD: Expecting ',' delimiter: line 1 column 1231 (char 1230)
# Extraído: ABC Spray 10mg/ml 30ml
# Extraído: Naridrin 12 Horas 1mg/ml + 0,2mg/ml + 5mg/ml 30ml
# Extraído: Cataflam Pro XT 23,2mg/g Emugel 100g
# Extraído: Humulin N NPH 100UI/ml 2 Refis de 3ml cada
# Extraído: Dorflex 10 comprimidos
# Extraído: Aerolin 100mcg/dose 200 doses 14,6 ml
# Extraído: Gotas Preciosas 30ml
# Extraído: Apresolina 50mg 20 drágeas
# Extraído: Apresolina 25mg 20 drágeas
# Extraído: Solução para Lentes Rígidas Boston Simplus Multiação 120ml
# Extraído: Doss 2.000UI Vitamina D3 30 cápsulas gelatinosas moles
# Extraído: Analgésico Dorflex 36 comprimidos
# Extraído: Flebodia 600mg 30 comprimidos revestidos
# Extraído: Melagrião Xarope 150ml
# Extraído: Puran T4 37,5mcg 30 comprimidos
# Extraído: DuploStat 800mg Abbott 60 Cápsulas Gelatinosas Moles
# Extraído: Lactolínea 667mg/ml Sabor Ameixa 120ml
# Extraído: Metamucil Sabor Laranja 10 sachês com 5,85g
# Extraído: Torsilax Neo Química 30 comprimidos
# Extraído: LuftaGastroPro Sachê 10ml
#   -> Aviso: Erro ao ler JSON-LD:Extraído: Muvinlax Sabor Limão 20 sachês
#  Expecting ',' delimiter: line 1 column 596 (char 595)
# Extraído: Inilok 40mg Apsen 60 comprimidos
# Extraído: Labirin 24mg 30 comprimidos
# Extraído: Atensina 0,150mg 30 comprimidos
# Extraído: Nootropil 800mg 30 comprimidos revestidos
# Extraído: Salonpas Adesivos Pequeno 10un
# Extraído: Prolive 30 cápsulas
# Extraído: Bifilac GeFlora Probióticos 14 sticks
# Extraído: Puran T4 75mcg 30 comprimidos
# Extraído: Vecasten 26,7mg 30 comprimidos
# Extraído: Bye Bad 4 cápsulas
# Extraído: Kalonat 20% 10ml
# Extraído: AAS Protect 100mg 30 comprimidos revestidos de liberação entérica
# Extraído: Antiverrugas Pointts 80ml
# Extraído: Sal de Frutas Eno Laranja 2 envelopes com 5g
# Extraído: Chá Stilgrip Sabor Mel e Limão 5g
# Extraído: Probiótico ProHN 30 cápsulas
# Extraído: Sulfato Ferroso 125mg/ml Arte Nativa Sabor Framboesa 30ml
# Extraído: Lufta GastroPro 12 sachês com 10ml
# Extraído: PlantaBen 3,5g Pó Efervescente Sabor Laranja 30 envelopes
# Extraído: Alginac 1.000 15 comprimidos revestidos
#   -> Aviso: Erro ao ler JSON-LD: Expecting ',' delimiter: line 1 column 510 (char 509)
# Extraído: Rosucor EZE 20mg + 10mg 30 cápsulas duras
# Extraído: Oscillococcinum 30 Tubos
# Extraído: Sal de Andrews Efervescente 1 envelope com 5g
# Extraído: Viofta 0,15% 10ml
# Extraído: Salonpas Adesivos Pequeno 4un
# Extraído: Plenance EZE 20mg+10mg 30 Cápsulas
# Extraído: Novolin R 100UI/ml 1 ampola com 10ml
# Extraído: Lacday 10.000 FCC ALU EMS 60 comprimidos mastigáveis
# Extraído: Ablok 25mg 30 comprimidos
# Extraído: Gaze de Rayon Pielsana 7,5cm X 7,5cm 3ml
# Extraído: Salonpas Adesivos Gel-Patch 3un
# Extraído: Puran T4 100mcg 30 comprimidos
# Extraído: Spray Nasal Snif Jet 0,9% 100ml
# Extraído: Varivax 300mg 30 comprimidos
# Extraído: Clob - X 0,5mg/ml Shampoo 125ml
# Extraído: Slow - K 600mg 20 drágeas
# Extraído: Loratamed 10mg Cimed 12 comprimidos
# Extraído: CataflamPRO Emulgel 150g
# Extraído: Aspirina Prevent 100mg 30 comprimidos revestidos
# Extraído: Almeida Prado N°46 60 comprimidos
# Extraído: Anya 1mg 30 comprimidos
# Extraído: Sonrisal Sabor Tradicional 2 comprimidos efervescentes
# Extraído: Doss Zinco 2000UI + 20mg 60 cápsulas gelatinosas moles
# Extraído: Puran T4 62,5mcg 30 comprimidos
# Extraído: Citoneurin 5.000 100mg + 100mg + 5.000mcg 60 comprimidos revestidos
# Extraído: Bicarbonato de Sódio ADV 100g
# Extraído: Concor HCT 5mg + 12,5mg 30 comprimidos revestidos
# Extraído: Inilok 40mg Apsen 30 Comprimidos
# Extraído: Almeida Prado N 28 60 Comprimidos
# Extraído: Expec Xarope Sabor Framboesa e Caramelo 120ml
# Extraído: Ritmoneuran RTM 20 Cápsulas
# Extraído: Suplemento Alimentar Lipomax Cromo 60 cápsulas
# Extraído: Alenia Refil 12mcg + 400mcg 60 cápsulas inalatórias
# Extraído: Novalgina 1g 10 comprimidos
# Extraído: Lacto-Purga 16 comprimidos revestidos
# Extraído: Dozemast Mecobalamina 1000mcg Com 30 Comprimidos Sublinguais
# Extraído: Actonel Chronos 35mg 4 comprimidos revestidos de liberação retardada
# Extraído: Puran T4 125mcg 30 comprimidos
# Extraído: Varicell 500mg 30 cápsulas
# Extraído: Chá Vick Pyrena Sabor Mel e Limão 5g
# Extraído: Tanakan 120mg 30 comprimidos revestidos
# Extraído: Sanasar Sabonete 100mg/g 60g
# Extraído: Flexalgin 300mg + 125mg + 50mg + 30mg 30 comprimidos
#   -> Aviso: Erro ao ler JSON-LD: Expecting ',' delimiter: line 1 column 510 (char 509)
# Extraído: Rosucor EZE 10mg + 10mg 30 cápsulas duras
# Extraído: Eniagor 50mg/ml Solução Capilar Refil 50ml
# Extraído: Azukon MR 30mg 100 comprimidos de liberação prolongada
# Extraído: Elixir Paregórico 30ml
# Extraído: Salonpas Adesivos Grande 4 unidades
# Extraído: Femibion 2 28 comprimidos + 28 cápsulas
# Extraído: Pradaxa 75mg 30 cápsulas
# Extraído: Diupress 25mg + 5mg 30 comprimidos
# Extraído: Metamucil Sabor Laranja 174g
# Extraído: Lubrificante Ocular Laxime 0,15% 10ml
# Extraído: Trezete 10mg + 10mg Aché, 30 comprimidos
# Extraído: Avamys Spray Nasal 27,5mg 120 doses 9,1ml
# Extraído: Probiótico GinoBiotta Com 30 cápsulas
# Extraído: Triancil 20mg/ml Solução Injetável 5 frascos-ampola com 1ml cada
# Extraído: Neo Fólico 5mg Neo Química 20 comprimidos revestidos
# Extraído: Vitamina D3 50.000UI Althaia 10 Cápsulas Moles
# Extraído: Vitacid 0,25mg/g Gel 25g
# Extraído: Óleo Sachet Pielsana 7,5cm X 15cm 5ml
# Extraído: Caldê 60 comprimidos mastigáveis
# Extraído: Buscopan Composto 20 comprimidos revestidos
# Extraído: Colic Calm Suspensão Oral 59ml
# Extraído: Levoid 38mcg 30 comprimidos
# Extraído: Ad-Til Gotas 20ml
# Extraído: Azelan Gel 150mg/g 30g
# Extraído: Bramicar HCT 80mg + 12,5mg 60 comprimidos
# Extraído: Teste de Gravidez Fast Test 1un
# Extraído: Sonridor Caf 2 comprimidos efervescentes
# Extraído: Puran T4 88mcg 30 comprimidos
# Extraído: Implanon NXT 68mg 1 aplicador contendo 1 implante
# Extraído: Calotrat Hertz Solução 5ml
# Extraído: Dramin B6 30ml
# Extraído: Suplemento Capilar Pantogar Neo 60 Cápsulas
# Extraído: Probiatop 30 sachês com 1g
# Extraído: Hidraplex Sabor Natural 4 envelopes
# Extraído: Elixir Galenogal 150ml
# Extraído: Hidraplex Natulab Sabor Água de Coco 04 envelopes
# Extraído: Ozempic 1 mg 1 carpule de 3ml + 1 sistema para aplicação + 4 agulhas novofine
# Extraído: Pepsamar Sabor Menta 10 comprimidos mastigáveis
# Extraído: Tapazol 5mg 100 comprimidos
# Extraído: Neutrofer Prev 60ml
# Extraído: Arnica Montana 6CH Almeida Prado Frasco com 13g
#   -> Aviso: Erro ao ler JSON-LD: Expecting ',' delimiter: line 1 column 492 (char 491)
# Extraído: Digeliv 400GaIU 15 comprimidos mastigáveis
# Extraído: Utrogestan 100mg 30 cápsulas
# Extraído: Insulina Fiasp 100U FlexTouch 3ml Com 1 Caneta
# Extraído: Calcitran D3 1000UI 60 comprimidos revestidos
# Extraído: Neosaldina 30 drágeas
# Extraído: Berotec 100mcg/ml 200 doses 10ml
# Extraído: Venzer 32mg 30 comprimidos
# Extraído: Acetilcisteína Endovenoso/Inalatório 100mg/ml União Química 5 ampolas de 3ml
# Extraído: Calcitran MDK Sabor Menta 30 comprimidos mastigáveis
# Extraído: Doss 3.000UI Vitamina D3 30 cápsulas gelatinosas moles
# Extraído: Zomig OD 2,5mg 2 comprimidos orodispersíveis
# Extraído: Venaflon 450mg + 50mg 60 comprimidos revestidos
# Extraído: Allurene 2mg 28 comprimidos
# Extraído: Diovan 160mg 28 comprimidos revestidos
# Extraído: Dramin B6 30 comprimidos revestidos
# Extraído: Apresolina 50mg 60 drágeas
# Extraído: Lidogel 20mg/g Neo Química Geleia 2% 30g
# Extraído: Tandene 30 comprimidos
# Extraído: Clopin Duo 75mg + 100mg 30 comprimidos revestidos
# Extraído: Imosec 2mg 12 comprimidos
# Extraído: Óleo Mineral União Química 100ml
# Extraído: Retemic 5mg 60 comprimidos
# Extraído: Plenance 10mg 90 comprimidos revestidos
# Extraído: Dulcolax 5mg 20 drágeas
# Extraído: Caltrate Ca 600mg + D3 200 UI 30 comprimidos revestidos
# Extraído: Solução Injetável Prolia 60mg 1 Seringa com 1ml Refrigerado
# Extraído: Apevitin BC Xarope 240ml
# Extraído: Sal de Frutas Eno Tabs Sabor Frutas Sortidas 48 comprimidos mastigáveis
# Extraído: Motix Solução Injetável 10 ampolas com 2,2ml cada
# Extraído: Ibandronato de Sódio Monoidratado 150mg EMS 1 comprimido revestido
# Extraído: Rosucor EZE 5mg +10mg 30 cápsulas duras
# Extraído: Laxante Minilax 7 bisnagas com 6,5g
# Extraído: Deltametril D 4% Emulsão Capilar 100ml
# Extraído: Cetobeta Creme 30g
# Extraído: Glyxambi 25mg + 5mg 30 comprimidos revestidos
# Extraído: Sinudoron Weleda 50ml
# Extraído: Dprev 14.000ui 4 comprimidos revestidos
# Extraído: Proctocaps 20 cápsulas
# Extraído: Nesina 25mg 30 comprimidos revestidos
# Extraído: Condroflex 500mg + 400mg 90 cápsulas
# Extraído: Neutrofer 300mg 30 comprimidos revestidos
# Extraído: Doralgina Neo Química 20 drágeas
# Extraído: Somalgin Cardio 100mg 60 comprimidos revestidos de dupla camada
# Extraído: Leucogen 80mg 30 cápsulas
# Extraído: Engov 24 comprimidos
# Extraído: Xantinon 30 comprimidos revestidos
# Extraído: Trezor 10mg 30 comprimidos revestidos
# Extraído: Folacin Sabor Laranja Gotas 30ml
# Extraído: Magnésia Bisurada Sabor Menta 10 pastilhas
# Extraído: Buscopan Gotas 10mg 20ml
# Extraído: Rozex 7,5mg/g Gel 30g
# Extraído: Nicorette 4mg Icemint 30 gomas mastigáveis
# Extraído: Miosan 10mg 10 comprimidos revestidos
# Extraído: AAS Infantil 100mg com 30 comprimidos
# Extraído: Solução Tópica Pantogar Top 80ml
# Extraído: Bisalax 5mg 20 drágeas
# Extraído: Flavonid 900mg + 100mg 30 comprimidos revestidos
# Extraído: DPrev 2.000UI 60 comprimidos revestidos
# Extraído: Flexive CDM Creme 50g
# Extraído: Imecap Hair Cabelos e Unhas 30 cápsulas
# Extraído: Sumaxpro 50mg + 500mg 2 comprimidos revestidos
# Extraído: Trayenta 5mg 30 comprimidos revestidos
# Extraído: Fumasil 60 Comprimidos Orodispersíveis
# Extraído: Bravan HCT 160mg + 12,5mg 30 comprimidos
# Extraído: Benestare 625mg 30 comprimidos revestidos
# Extraído: Aspirina C 2 Sabor Limão comprimidos efervescentes
# Extraído: Allegra Pediátrico 6mg/ml 150ml
# Extraído: Vitafer 109mg 50 comprimidos revestidos
# Extraído: Vaporizante Descongestionante Vick VapoRub Unguento 100g
# Extraído: Nebacetin Pomada 15g
# Extraído: Resfenol 20 cápsulas
# Extraído: Synthroid 50mcg 30 comprimidos
# Extraído: Lasix 40mg 20 comprimidos
# Extraído: Somalgin Cardio 81mg, 60 Comprimidos Revestidos de Dupla Camada
# Extraído: Almeida Prado N 48 60 Comprimidos
# Extraído: Levoid 75mcg 30 comprimidos
# Extraído: ESTREVA - 0,1%, 1 frasco com 50g de gel de uso dermatológico
# Extraído: Neosaldina 4 drágeas
# Extraído: Ferropurum 20mg/ml 5 ampolas de 5ml
# Extraído: Neosaldina 20 drágeas
# Extraído: Puran T4 25mcg 30 comprimidos
# Extraído: Suplemento Alimentar Pealiv 300mg Myralis 30 Comprimidos
# Extraído: SeloZok 50mg 30 comprimidos revestidos de liberação controlada
# Extraído: Combigan Solução Oftálmica 0,2% + 0,5% 10ml
# Extraído: Angino Rub Sabor Menta Com 16 Pastilhas
# Extraído: Combi AD 30ml + seringa dosadora
# Extraído: ZincoPro Probiótico 30 cápsulas
# Extraído: Artroflan 150mg 60 comprimidos revestidos
#   -> Aviso: Erro ao ler JSON-LD: Expecting ',' delimiter: line 1 column 769 (char 768)
# Extraído: Vagifem 10mcg 18 comprimidos vaginais com aplicadores individuais
# Extraído: Soolantra 10mg/g Creme Dermatológico 30g
# Extraído: Monessa 90 cápsulas
# Extraído: Magnésia Bisurada Sabor Menta 40 pastilhas
# Extraído: Floratil AT 250mg 10 envelopes de 1,25g
# Extraído: Synthroid 112mcg 30 comprimidos
# Extraído: Doss 7.000UI 30 cápsulas gelatinosas moles
# Extraído: Levty 10.000 U.FCC 30 comprimidos
# Extraído: Xarope Fluimucil Pediátrico 20mg/ml Sabor Framboesa 120ml
# Extraído: Slinda 4mg 28 comprimidos revestidos
# Extraído: Salonpas Adesivos Grande 2un
# Extraído: Bicarbonato de Sódio ADV 10 Sachês de 2,5g cada
# Extraído: Ofolato SOP Sabor Tangerina 30 sachês
# Extraído: Solução Nasal Sinustrat Vasoconstritor 0,5mg/ml 10ml
# Extraído: Alta D 15.000UI 4 cápsulas moles
# Extraído: Citoneurin 5.000mcg 30 comprimidos revestidos
# Extraído: Ceci 2mg + 1mg 28 comprimidos revestidos
# Extraído: UroCran Cranberry 500mg 30 Cápsulas
# Extraído: Loção Pediletan 1% 60ml + Pente Fino
# Extraído: Lacday 10.000 U.FCC EMS 30 comprimidos mastigáveis
#   -> Aviso: Erro ao ler JSON-LD: Expecting ',' delimiter: line 1 column 1256 (char 1255)
# Extraído: Latanoprosta 50mcg/ml Geolab 2,5ml
# Extraído: Doss 1.000UI Vitamina D3 90 cápsulas gelatinosas
# Extraído: Hidraplex Natulab Sabor Guaraná 04 envelopes
# Extraído: SeloZok 25mg 60 comprimidos revestidos de liberação controlada
# Extraído: Gel de tratamento Antiacne Dermotivin Benzac 10% 60g
# Extraído: Glargilin 100ui/ml 1 refil de 3ml
# Extraído: Artrolive 1500mg + 1200mg Sabor Laranja 30 envelopes com 4g de granulado cada
# Extraído: Suganon 5mg 30 comprimidos revestidos
# Extraído: Vaporizante Descongestionante Vick VapoRub Unguento 12g
# Extraído: Cetobeta Pomada 30g
# Extraído: Vitamina D Sof D 7.000 UI 8 cápsulas gelatinosas moles
# Extraído: Sal de Frutas Eno Limão 2 envelopes com 5g
# Extraído: Venaflon 450mg + 50mg 30 comprimidos revestidos
# Extraído: NORIPURUM EV - 20mg/mL, 5 ampolas com 5mL de solução injetável
# Extraído: Vitamina D3 Althaia 7.000 UI 8 cápsulas moles
# Extraído: Hidraplex Natulab Sabor Tutti-Frutti 4 envelopes
# Extraído: Benegrip 20 comprimidos revestidos
# Extraído: Busonid Aquoso Nasal 50mcg 120 doses 6ml
# Extraído: Tylenol Sinus 500g + 30mg 24 comprimidos revestidos
# Extraído: Flebon 50mg 30 comprimidos
# Extraído: Zart 50mg 30 comprimidos revestidos
# Extraído: Motix Pomada 50g
# Extraído: Stanglit 45mg 30 comprimidos
# Extraído: Flancox 600mg 14 comprimidos
# Extraído: Clorana 25mg 30 comprimidos
# Extraído: Ginkgo Vital 80mg 30 comprimidos
# Extraído: Glivance XR 500mg + 30mg 30 Comprimidos de Liberação Prolongada
# Extraído: Estomazil Sabor Abacaxi 5g
# Extraído: Cefaliv Aché 12 comprimidos
# Extraído: Esmalte Loceryl 50mg/ml 2,5ml
# Extraído: Thealoz Duo Solução Oftálmica 10ml
# Extraído: Dorflex 24 comprimidos
# Extraído: Natifa Pro UBD 0,5mg + 0,1mg 28 comprimidos revestidos
# Extraído: Naprix D 5mg + 12,5mg 30 cápsulas duras
# Extraído: Luftal Gotas 75mg/ml Sabor Cereja 15ml
# Extraído: Salonpas Gel 40g
# Extraído: Angino Rub Sabor Mel e Limão Com 16 Pastilhas
# Extraído: Ferro 100mg Biolab 30 comprimidos mastigáveis
# Extraído: Minancora Pomada 30g
# Extraído: Siilif 100mg 60 comprimidos revestidos
# Extraído: Addera D3 50.000UI 4 cápsulas moles
# Extraído: Antiácido Gastrol Blister 20 Pastilhas
# Extraído: Neutrofer 500mg 30 comprimidos revestidos
# Extraído: Iumi ES 3mg + 0,02mg 120 comprimidos
# Extraído: Glifage 500mg 30 comprimidos revestidos
# Extraído: Noripurum 50mg/ml Gotas 30ml
# Extraído: Castanha da Índia Atalaia 30 drágeas
# Extraído: Dozoito 25mg 30 comprimidos
# Extraído: Engov 6 comprimidos
# Extraído: Kit Solução para Lentes Bio Soak Olhos Sensíveis 360ml+120ml + Estojo para Lentes
# Extraído: Ferinject 50mg/ml 1 ampola com 10ml
# Extraído: Vitergan Zinco PL 30 comprimidos revestidos
# Extraído: Valerimed 50mg 20 comprimidos revestidos
# Extraído: Almeida Prado N 18 60 Comprimidos
# Extraído: Capilarema 75mg 60 comprimidos
# Extraído: Venaflon 900mg + 100mg 60 comprimidos
# Extraído: Thioctacid 600 mg 30 comprimidos revestidos
# Extraído: Buclina 25mg 30 comprimidos
# Extraído: Plenance EZE 10mg+10mg 30 cápsulas
# Extraído: Decongex Plus 12 comprimidos
# Extraído: Rosucor 10mg 60 comprimidos revestidos
# Extraído: Decacron 4mg/ml Solução Injetável com 2,5ml
# Extraído: Zinpass EZE 10mg + 10mg 30 comprimidos revestidos
# Extraído: Soanza XR 35mg 60 comprimidos
# Extraído: Benerva 300mg 30 comprimidos revestidos
# Extraído: Resolor 1mg 14 comprimidos revestidos
# Extraído: Puran T4 112mcg 30 comprimidos
# Extraído: Espinheira Santa 380mg Herbarium 45 Cápsulas Duras
# Extraído: Indapen SR 1,5mg 30 comprimidos revestidos de liberação prolongada
# Extraído: Noripurum 100mg 30 comprimidos mastigáveis
# Extraído: Neutrofer 150mg 30 comprimidos revestidos
# Extraído: Allegra Pediátrico 6mg/ml 60ml
# Extraído: Neosaldina 10 drágeas
# Extraído: Probid 15 cápsulas
# Extraído: 20 Bi Probiótico com 30 cápsulas
# Extraído: Jardiance 10mg 30 comprimidos revestidos
# Extraído: Artrolive 500mg + 400mg 90 cápsulas
# Extraído: Tylenol Bebê 100mg/ml Sabor Frutas 15ml + Seringa Dosadora
# Extraído: Condroflex 1,5g + 1,2g 30 sachês com pó para solução oral
# Extraído: Level 0,10mg + 0,02mg 63 comprimidos revestidos
# Extraído: Naramig 2,5mg 4 comprimidos revestidos
# Extraído: Chá Vick Pyrena Sabor Camomila e Erva-Cidreira 5g
# Extraído: Ancoron 100mg 60 comprimidos revestidos
# Extraído: Almeida Prado N 16 60 Comprimidos
# Extraído: Neutrofer 250mg/ml Gotas 30ml
# Extraído: Citobê 100mg + 100mg + 5000mcg 30 comprimidos revestidos
# Extraído: Cloreto de Magnésio PA Ifal 33g
# Extraído: Clenil HFA Spray 50mcg 200 doses 10ml
# Extraído: Phosfoenema Laxante 130ml
# Extraído: Annita 500mg, 6 comprimidos revestidos
# Extraído: Naldecon Multi 16 comprimidos
# Extraído: Moment 0,25mg/ml 60ml
# Extraído: Besomed Almeida Prado 60 comprimidos
# Extraído: Aspirina 500mg 10 comprimidos
# Extraído: Icaden 10mg/g Creme Dermatológico 20g
# Extraído: Descongestionante Inalante Vick Bastão 0,5g
# Extraído: Doss 7.000UI 12 cápsulas gelatinosas moles
# Extraído: Peg-Lax 17g Pó para Solução Sabor Limão 14 envelopes
# Extraído: Strepsils Sabor Laranja 16 pastilhas
# Extraído: Nasonex Spray Nasal 120 doses 17ml
# Extraído: Metamucil Pó Sabor Original 210g
# Extraído: Def B 1.000mcg 30 comprimidos sublinguais
# Extraído: Estomazil Pastilhas Sabor Abacaxi 20 comprimidos mastigáveis
# Extraído: Condroflex 1,5g + 1,2g Sabor Abacaxi 30 sachês com pó para solução oral
# Extraído: Neo B 100mg + 100mg + 5000mcg 60 comprimidos revestidos
# Extraído: Qlaira Bayer 26 comprimidos ativos + 2 comprimidos inativos
# Extraído: Rinosoro Gotas 0,9% 30ml
# Extraído: CLIMENE - (2mg) + (2mg + 1mg), 21 drágeas
# Extraído: Oestrogel 0,6mg/g Gel 80g
# Extraído: Traumeel S Pomada 50g
# Extraído: Enterogermina 10 frascos de 5ml
# Extraído: Renitec 10mg 30 comprimidos
# Extraído: Zinpass Eze 20mg + 10mg 30 comprimidos revestidos
# Extraído: Sandrena 0,5mg Gel 28 sachês com 0,5g
# Extraído: Eparema Sabor Laranja 10ml
# Extraído: Sigmatriol 0,25mcg 30 cápsulas gelatinosas moles
# Extraído: Eparema Sabor Hortelã 10ml
# Extraído: Pressat 2,5mg 60 comprimidos
# Extraído: Oscillococcinum 6 Tubos
# Extraído: Yaz 3mg + 0,02mg 24 + 4 comprimidos revestidos
# Extraído: Novalgina 500mg/ml 20ml
# Extraído: Nevralgex 300mg + 50mg + 35mg 30 comprimidos
# Extraído: Euthyrox 50mcg 50 comprimidos
# Extraído: Flexive CDM Creme 25g
# Extraído: Alginac Retard 10 comprimidos revestidos de liberação retardada
# Extraído: Eniagor 50mg/ml Solução Capilar 2 frascos 50ml cada
# Extraído: Buscofem 400mg 10 cápsulas
# Extraído: Vonau Flash 4mg, Sabor Menta 10 comprimidos de desintegração oral
# Extraído: Trezor 5mg 30 comprimidos
# Extraído: Reuquinol 400mg 30 comprimidos revestidos
# Extraído: Gynpro 100mg 30 cápsulas moles
# Extraído: Micardis 80mg 30 comprimidos
# Extraído: Probiótico Probians 30 cápsulas
# Extraído: Natrilix SR 1,5mg 60 comprimidos revestidos de liberação prolongada
# Extraído: Neolefrin Dia Neo Química 20 comprimidos
# Extraído: Nebacetin Pomada 50g
# Extraído: Antiácido Sonrisal Sabor Limão 2 comprimidos efervescentes
# Extraído: Advil 400mg 20 cápsulas líquidas
# Extraído: Cicloprimogyna 2mg + 2mg + 0,25mg 21 drágeas
# Extraído: Lactulona 667mg/ml Xarope Sabor Ameixa 120ml
# Extraído: Allegra 180mg 10 comprimidos revestidos
# Extraído: Pant Sec 50mg/ml 1 válvula spray 50ml
# Extraído: Bramicar HCT 40mg + 12,5mg 30 comprimidos
# Extraído: Novalgina 1g 20 comprimidos
# Extraído: Busonid Aquoso Nasal 32mcg 120 doses 6ml
# Extraído: Januvia 100mg 28 comprimidos revestidos
# Extraído: Desodalina 600mg 60 cápsulas
# Extraído: Gestinol 30mcg + 75mcg 84 comprimidos revestidos
# Extraído: Fluimucil D 600mg 16 envelopes com 5g cada
# Extraído: Gino Canesten 1 Dia 500mg 1 comprimido vaginal + 1 aplicador
# Extraído: Keltrina Plus Emulsão 5% Fragrância de Erva Doce 60ml
# Extraído: Hirudoid 500 5mg/g Pomada 40g
# Extraído: Meritor 2mg + 1000mg 30 comprimidos revestidos
# Extraído: Bravan HCT 80mg + 12,5mg 30 comprimidos
# Extraído: Luftal Gel Caps 125mg 10 cápsulas gelatinosas
# Extraído: Clopin 75mg 30 comprimidos revestidos
# Extraído: Novoprazol 20mg 56 Cápsulas
# Extraído: Pant 50mg/ml Refil 50ml
# Extraído: Metrexato 2,5mg 24 comprimidos
# Extraído: Gamaline V 900mg 30 cápsulas moles
# Extraído: Ginkoba 80mg 30 comprimidos revestidos
# Extraído: Januvia 50mg 28 comprimidos revestidos
# Extraído: Cyclofemina 25mg + 5mg Solução Injetável 1 ampola com 0,5ml
# Extraído: Dermosalic 0,5mg/ml + 20,0mg/ml 30ml
# Extraído: Loção Oleosa Dersani 100ml
# Extraído: Betadine XR 48mg 30 comprimidos
# Extraído: Kollagenase Pomada 0,6U/g 30g
# Extraído: Loratadina 1mg/ml, Cimed 100ml
# Extraído: Flancox 500mg 14 comprimidos revestidos
# Extraído: Sal de Frutas Eno Laranja 100g
# Extraído: Fluimucil 600mg Sabor Limão 16 comprimidos efervescentes
# Extraído: Omcilon-A Orabase 1mg/g Pomada 10g
# Extraído: Xantinon 10 comprimidos revestidos
# Extraído: Mylanta Plus Antiácido Sabor Morango 240ml
# Extraído: Adoless 3 0,060mg + 0,015mg 84 comprimidos revestidos
# Extraído: Teste de Gravidez Fast Test Plus 1 Unidade
# Extraído: Pastilhas Strepsils Sabor Mel e Limão 16 pastilhas
# Extraído: Infralax 15 comprimidos
# Extraído: Synthroid 125mcg 30 comprimidos
# Extraído: Doss 1.000UI 30 cápsulas gelatinosas moles
# Extraído: Tanderalgin Delta 15 Comprimidos
# Extraído: Neutrofer Folato D 90 comprimidos revestidos
# Extraído: Advil 600mg 12 Horas 12 comprimidos revestidos de liberação prolongada
#   -> Aviso: Erro ao ler JSON-LD: Expecting ',' delimiter: line 1 column 500 (char 499)
# Extraído: Zetsim 10mg + 20mg 30 comprimidos
# Extraído: Livalo 2mg 60 comprimidos revestidos
# Extraído: Venalot 15mg + 90mg 60 comprimidos
# Extraído: Bonviva 150mg 1 comprimido revestido
# Extraído: Maxidrate Gel Nasal 6mg/g 30g
# Extraído: Allegra 60mg 10 comprimidos revestidos
# Extraído: Kaloba 825mg/ml Gotas 20ml
# Extraído: Acheflan 5mg/g Aerossol 75ml
# Extraído: Synthroid 75mcg 30 comprimidos
# Extraído: Histamin 2mg 20 comprimidos
# Extraído: Óleo Mineral ADV Farma 100% Puro 100ml
# Extraído: Ozempic 0,25mg 1 carpule de 1,5ml + 1 sistema para aplicação + 6 agulhas novofine
# Extraído: Doss 50.000UI 4 cápsulas gelatinosas moles
# Extraído: Calcitran D3 1000ui 30 comprimidos revestidos
# Extraído: Torsilax Neo Química 12 comprimidos
# Extraído: Natifa 1mg 28 comprimidos revestidos
# Extraído: Lacass 66,66mg 14 comprimidos revestidos
# Extraído: Tylenol Gotas 200mg/ml Sabor Frutas 15ml
# Extraído: Floratil AT 250mg 10 cápsulas
# Extraído: Advil Mulher 400mg 2 cápsulas líquidas
# Extraído: Zyloric 100mg 30 comprimidos
# Extraído: Euthyrox 25mcg 50 comprimidos
# Extraído: Ofolato D 2.000 UI 30 comprimidos
# Extraído: Suplemento Alimentar Zirvit Pré 30 cápsulas
# Extraído: Colact 667mg/ml Sabor Ameixa 120ml
# Extraído: Concor Anlo 5/5 mg 30 comprimidos
# Extraído: Glicel 2,5g Adulto 6 supositórios de glicerina
# Extraído: Neo Fedipina 20mg 30 comprimidos
# Extraído: Silimalon 70mg + 100mg 10 comprimidos revestidos
# Extraído: Trezete 20mg + 10mg 30 Comprimidos Revestidos
# Extraído: Stodal Xarope 150ml
# Extraído: Suprema 2mg + 1mg 28 comprimidos revestidos
# Extraído: Therapsor 0,5mg/ml Solução Capilar 25ml
# Extraído: Galvus Met 50mg + 1000mg 56 comprimidos revestidos
# Extraído: Diosmin 450mg + 50mg 60 comprimidos revestidos
# Extraído: Lisador Dip 1g 20 comprimidos
# Extraído: Caltren 10mg 30 comprimidos
# Extraído: Vitanol A 0,25mg/g 30g Creme Dermatológico
# Extraído: Digeplus 7mg + 40mg + 50mg Aché 30 Cápsulas
# Extraído: Epitegel 50mg/g Gel Oftálmico 10g
# Extraído: Diamox 250mg 30 comprimidos
# Extraído: Janumet 50mg + 1000mg 56 comprimidos revestidos
#   -> Aviso: Erro ao ler JSON-LD: Expecting ',' delimiter: line 1 column 1017 (char 1016)
# Extraído: Lugano 12mcg + 250mcg Refil 60 cápsulas com pó para inalação
# Extraído: Ablok Plus 25mg + 12,5mg 60 comprimidos
# Extraído: Xarope Leucogen Sabor Caramelo 120ml
# Extraído: Tylenol Sinus 500mg + 30mg 36 comprimidos revestidos
# Extraído: Trezor 40mg 30 comprimidos revestidos
# Extraído: Luftal 40mg 20 comprimidos
# Extraído: Tylenol 750mg 10 comprimidos revestidos
# Extraído: Inzelm 20mg 30 Comprimidos Revestidos
# Extraído: Press Plus 5mg + 20mg 60 cápsulas
# Extraído: Dramin CapsGel 50mg 10 Cápsulas Mole
# Extraído: Dorflex Max 8 comprimidos
# Extraído: Creon 10.000 30 cápsulas com minimicroesferas acidorresitentes
# Extraído: Auris-Sedina 18,6mg/ml + 1,3mg/ml 10ml
# Extraído: Pastilhas para Garganta Strepsils Sabor Mel e Limão 8 pastilhas
# Extraído: Canesten Creme 10mg/g 20g
# Extraído: Edistride 10mg 30 comprimidos
# Extraído: Naprix A 5mg + 5mg 30 cápsulas
# Extraído: Foldan 50mg/g Pomada 45g
# Extraído: Perlatte 9.000 fcc 10 comprimidos
# Extraído: Bexai 35mg 20 capsúlas
# Extraído: Belarina 2mg + 0,02mg 28 comprimidos revestidos
# Extraído: Buscopan Composto 4 comprimidos revestidos
# Extraído: Toragesic 10mg 10 comprimidos sublinguais
# Extraído: Sal de Frutas Eno Tradicional 100g
# Extraído: Tandrilax Aché 30 comprimidos
# Extraído: Cistitemed Almeida Prado 60 comprimidos
# Extraído: AlleNasal Spray Nasal Antialérgico 120 Doses 16,5ml
# Extraído: Hirudoid 500 5mg/g Gel 40g
# Extraído: Niki 3mg + 0,02mg 72 comprimidos revestidos
# Extraído: Benegrip 12 comprimidos revestidos
# Extraído: Advil 400mg 8 cápsulas líquidas
# Extraído: AtivB 1000mcg 30 comprimidos sublinguais
# Extraído: Pressat 2,5mg 30 comprimidos
# Extraído: Dorilen Gotas 15ml
# Extraído: Luftal Gel Caps 125mg 20 Cápsulas Gelatinosas
# Extraído: Allestra 20 75mcg + 20mcg 63 drágeas
# Extraído: Coristina D Pro 16 comprimidos
# Extraído: Ginkoba 120mg 30 comprimidos revestidos
# Extraído: Tâmisa 20 75mcg + 20mcg 63 comprimidos revestidos
# Extraído: Iumi ES 3mg + 0,02mg 30 comprimidos revestidos
# Extraído: Dutam 0,5mg + 0,4mg 30 cápsulas gelatinosas duras de liberação prolongada
# Extraído: Doss Zinco 2.000UI + 20mg 30 cápsulas gelatinosas
# Extraído: Antigases Luftal Infantil Gotas 75mg/ml Sabor Cereja 15ml
# Extraído: Nactali 75mcg 84 comprimidos revestidos
# Extraído: Hytós Plus Xarope  Sabor Tutti Frutti 100ml
# Extraído: Óleo de Girassol Skinage 100ml
# Extraído: Vonau Flash 4mg Biolab 10 comprimidos de desintegração oral
# Extraído: Dorflex Gotas 20ml
# Extraído: Nevralgex Cimed 10 comprimidos
# Extraído: Descongestionante Nasal Sorine SSC 0,9% Spray Suave Jato Contínuo 100ml
# Extraído: Clexane 40mg/0,4ml 6 seringas preenchidas com 0,4ml com sistema de segurança
# Extraído: Teste de Gravidez Confira Pratic 1un
# Extraído: Plasil 10mg 20 comprimidos
# Extraído: Brilinta 90mg 60 comprimidos revestidos
# Extraído: Maleato de Dexclorfeniramina 2mg EMS 20 comprimidos
# Extraído: Pomada Calotrat Plantar 200mg/g Kley Hertz 20g
# Extraído: Epiduo 1mg/g + 25mg/g Gel 30g
# Extraído: Rosucor 20mg 30 comprimidos revestidos
# Extraído: Coledue R 10mg + 10mg 30 cápsulas duras
# Extraído: Verrux 0,20g/ml + ,015ml/ml Solução 10ml
# Extraído: Cerumin Solução Otológica 8ml
# Extraído: Flanax 550mg 10 comprimidos revestidos
# Extraído: Maleato de Dexclorfeniramina 2mg/5ml EMS 120ml
# Extraído: Sumax 6mg/0,5ml Solução Injetável 1 seringa com 0,5ml
# Extraído: Selene 0,035mg + 2mg 21 comprimidos revestidos
# Extraído: Levoid 25mcg 30 comprimidos
# Extraído: Cedur Retard 400mg 30 comprimidos revestidos de liberação prolongada
# Extraído: Buscoplex Composto Gotas 20ml
# Extraído: Bravan HCT 160mg + 25mg 30 comprimidos
# Extraído: Benicar Triplo 40mg/12,5mg/5mg 30 comprimidos revestidos
# Extraído: Equitam 80mg 30 Comprimidos Revestidos
# Extraído: Malvona Solução Oral 200ml
# Extraído: Euthyrox 137mcg 50 comprimidos
# Extraído: Trezor 20mg 30 comprimidos revestidos
# Extraído: Decongex Plus Xarope 120ml
# Extraído: Gel Dersani Hidrogel com Alginato 85g
# Extraído: Advantan 1mg/g Creme Dermatológico 15g
# Extraído: Selene 0,035mg + 2mg 63 comprimidos revestidos
# Extraído: Solução Oftálmica Octifen 0,25mg/ml 5ml
# Extraído: Daflon 1000mg FFPM 30 comprimidos revestidos
# Extraído: Sal de Frutas Eno Guaraná 2 envelopes com 5g
# Extraído: Etna 2,5mg + 1,5mg + 1,0mg 20 cápsulas
# Extraído: Biofenac Aerossol 85ml
# Extraído: Finalop 1mg 30 Comprimidos Revestidos
# Extraído: Clifemin 160mg 30 comprimidos
# Extraído: Sinvastacor 10mg 30 comprimidos revestidos
# Extraído: Femoston Conti 1mg + 5mg 28 comprimidos revestidos
# Extraído: Folifolin 5mg EMS 30 comprimidos
# Extraído: Divena 40mg 30 comprimidos
# Extraído: Ogestan Gold 90 cápsulas
# Extraído: Silimalon 140mg + 100mg 60 comprimidos revestidos
# Extraído: Victoza 6mg/ml 2 carpules com 3ml + 2 sistemas de aplicação
# Extraído: Ciclo 21 União Química 21 comprimidos
# Extraído: Solução Nasal Sorine Jet Baby Jato Suave Contínuo 100ml
# Extraído: Proctyl Pomada 30g + 10 aplicadores
# Extraído: Lactulona 667mg/ml Xarope Sabor Salada de Frutas 120ml
# Extraído: Zimiex 10mg 30 comprimidos
# Extraído: Epiduo 0,3% 45g
# Extraído: Xarope Glyteol 200mg/15ml Sabor Morango 100ml
# Extraído: Complexo Homeopático Almeida Prado N 21 60 Comprimidos
# Extraído: Benicar Anlo 20mg + 5mg 30 comprimidos revestidos
# Extraído: Linadib 5mg 30 comprimidos revestidos
# Extraído: Flanax 275mg 8 comprimidos
# Extraído: DPrev 5.000UI 30 comprimidos revestidos
# Extraído: Arpadol 400mg, 60 Comprimidos
# Extraído: Sandrena 0,1mg Gel 28 sachês com 1g
# Extraído: Sal de Frutas Eno Tônica 2 envelopes com 5g cada
# Extraído: Winter Ap 6mg + 120mg 8 cápsulas
# Extraído: Cutisanol 1,5mg/g + 45mg/g Gel 100g
# Extraído: Tecnomet 2,5mg 20 comprimidos
# Extraído: Novalgina 500mg 10 comprimidos
# Extraído: Meticorten 5mg 20 comprimidos
# Extraído: Cronobê Complex 90 comprimidos revestidos
# Extraído: Vodol Creme 20mg/g 28g
# Extraído: Engov After Sabor Tangerina 250ml
# Extraído: Dexfer 100mg/ml Gotas Sabor doce de Leite 30ml
# Extraído: Iumi 3mg + 0,02mg 24 comprimidos revestidos
# Extraído: Miosan 5mg 10 comprimidos revestidos
# Extraído: Busonid Aquoso Nasal 64mcg 120 doses 6ml
# Extraído: Solução Injetável Endovenosa Manitol 20% 250ml
# Extraído: Ablok Plus 50mg + 12,5mg 60 comprimidos
# Extraído: Repopil 35 - 2mg + 0,035mg 21 comprimidos revestidos
# Extraído: Naridrin Solução Nasal 15ml
# Extraído: Naprix A 10mg + 10mg 30 cápsulas
# Extraído: Meritor 4mg + 1000mg 30 comprimidos revestidos
# Extraído: Sinvastacor 20mg 30 comprimidos revestidos
# Extraído: Trelegy 100 + 62,5 + 25mcg 1 Dispositivo com 30 Doses
# Extraído: Leite de Magnésia Phillips Original  350ml
# Extraído: Diovan Amlo Fix 320mg + 10mg 28 comprimidos revestidos
# Extraído: Levoid 50mcg 30 comprimidos
# Extraído: Anador 1g 10 comprimidos
# Extraído: Januvia 25mg 28 comprimidos revestidos
# Extraído: Lactase 10.000 U.FCC Equaliv  Sabor Creme 30 comprimidos mastigáveis
# Extraído: Allegra 120mg 10 comprimidos revestidos
# Extraído: Trombofob 200U Gel 40g
# Extraído: Ibupril 400mg 10 comprimidos
# Extraído: Naprix A 10mg + 5mg 30 cápsulas
# Extraído: Elani 28 3mg + 0,03mg 84 comprimidos revestidos
# Extraído: Perfenol 20 cápsulas
# Extraído: Natifa Pro 1mg + 0,5mg 28 comprimidos revestidos
# Extraído: Solução Oftálmica Glaucotrat 0,5% 5ml
# Extraído: Xarope Seki 120ml
# Extraído: Lavagem Nasal Nasoar XT 5,0% Refil 15 sachês
# Extraído: Dorflex 50 comprimidos
# Extraído: Alenia Refil 6mcg + 200mcg 60 cápsulas inalatórias
# Extraído: Alginac 5.000mcg + 100mg + 100mg + 75mg 3 ampolas com 1ml + 3 ampolas com 2ml
# Extraído: Meclin 25mg 15 comprimidos
# Extraído: Androsten UNO 280mg 15 comprimidos revestidos
# Extraído: Icaden Spray 10mg/ml 50ml
# Extraído: Pantogar Biolab 90 Cápsulas
# Extraído: Diprosalic 0,5mg/ml + 20mg/ml Solução Dermatológica 30ml
# Extraído: Imunoflan 307,39mg/ml Xarope 120ml
# Extraído: Symbicort Spray 6/100 mcg 120 doses de pó de uso inalatório
# Extraído: Novolin N Penfill 100UI/ml 5 carpules com 3ml cada
# Extraído: Allestra 15 60mcg + 15mcg 28 comprimidos
# Extraído: Benicar 20mg 30 comprimidos revestidos
# Extraído: Clob - X 0,5mg/ml Emulsão Dermatológica 59ml
# Extraído: Deriva Micro 1mg/g Gel de Liberação Controlada 30g
# Extraído: Floratil 200mg 6 cápsulas
# Extraído: Materna Ômega 3 DHA 30 cápsulas gelatinosas
# Extraído: Sucrafilm 200mg/m 20 flaconetes com 10ml cada
# Extraído: Brasart HCT 160mg + 12,5mg 90 comprimidos revestidos
# Extraído: Maxalgina 500mg/ml Gotas Sabor Abacaxi 20ml
# Extraído: Solução Oftálmica Glaub MD 0,1% 5ml
# Extraído: Repoflor 250mg 10 cápsulas duras
# Extraído: Tiorfan 100mg 9 cápsulas
# Extraído: Apracur 6 comprimidos
# Extraído: Solução Oftálmica Drusolol 2% + 5% 5ml
# Extraído: Osteoban 150mg 3 comprimidos
# Extraído: Dienogeste 2mg EMS 30 comprimidos
# Extraído: Ferronil 40mg 50 comprimidos revestidos
# Extraído: Advil 400mg 16 cápsulas líquidas
# Extraído: Enax 200mg 30 comprimidos revestidos
# Extraído: Dexfer 400mg, Eurofarma 30 comprimidos revestidos
# Extraído: Engov 12 comprimidos
# Extraído: Calicida Solução ADV 10ml
# Extraído: Synthroid 25mcg 30 comprimidos
# Extraído: Trok-N 20mg/g + 0,64mg/g + 2,5mg/g Creme 30g
# Extraído: Mesigyna 50mg/ml + 5mg/ml Solução Injetável 1 ampola com 1ml
# Extraído: Probiótico Enterogermina Plus 5 frascos de 5ml
# Extraído: OsteoNutri 600mg + 400UI 30 comprimidos revestidos
# Extraído: Myrafer 100mg/ml Sabor Doce de Leite 30ml
# Extraído: Glyxambi 10mg/ 5mg 30 Comprimidos Revestidos
# Extraído: Tamarine Geléia Zero Açúcar 150g
# Extraído: Vitergan Zinco 30 comprimidos revestidos
# Extraído: Gastrobion Sabor Cereja 240ml
# Extraído: Levoid 112mcg 30 comprimidos
# Extraído: Dozemast Mecobalamina 1000mcg Com 90 Comprimidos Sublinguais
# Extraído: Melagrião Própolis e Gengibre Spray Sabor Limão 30ml
# Extraído: Venaflon 900mg + 100mg 30 comprimidos
# Extraído: Zior 250mg 28 comprimidos
# Extraído: Guttalax Laxante 7,5mg/ml 30ml
# Extraído: Tapazol 10mg 100 comprimidos
# Extraído: Neblock 5mg 60 comprimidos
# Extraído: Rinosoro Jet XT 0,9% 100ml
# Extraído: Advil Mulher 400mg 10 Cápsulas Líquidas
# Extraído: Vitacid 0,5mg/g Creme 25g
# Extraído: Hiluropt 0,15% 10ml
# Extraído: Gino-Canesten Balance 7 bisnagas aplicadoras 5ml cada
# Extraído: Hixizine 25mg 30 comprimidos
# Extraído: Equitam 120mg 30 comprimidos revestidos
# Extraído: Concor 2,5mg 30 comprimidos revestidos
# Extraído: Peg-Lax 8,5g Pó para Solução Sem Sabor 14 envelopes
# Extraído: Coristina D Pro 4 comprimidos
# Extraído: Polaramine 10mg/g Creme 30g
# Extraído: Aldomet 250mg 30 comprimidos revestidos
# Extraído: Maxidex Solução Oftálmica 1mg/ml 5ml
# Extraído: Esomex 40mg 56 comprimidos revestidos de liberação retardada
# Extraído: Livalo 2mg 30 comprimidos revestidos
# Extraído: Labirin 16mg 30 comprimidos
# Extraído: Retemic 5mg 30 comprimidos
# Extraído: Androgel 50mg 30 envelopes com 5g de gel de uso dermatológico
# Extraído: Kaloba 825mg/ml Gotas 50ml
# Extraído: Ablok 50mg 30 comprimidos
# Extraído: Arnica Montana 6CH Almeida Prado Gotas 15ml
# Extraído: Naldecon Multi 4 comprimidos
# Extraído: Neutrofer Poli 30ml
# Extraído: Halobex 0,05% Creme Dermatológico 30g
# Extraído: Escabin Pro 4% Emulsão Capilar 100ml
# Extraído: Dexilant 60mg Takeda 30 cápsulas de liberação retardada
# Extraído: Inzelm 10mg 30 comprimidos revestidos
# Extraído: Colidis 5ml
# Extraído: Buscopan 10mg 20 drágeas
# Extraído: Osteotec 150mg 3 comprimidos revestidos
# Extraído: Emulsão Sanasar 250mg/ml 100ml
# Extraído: Biovicerin 12 flaconetes com 5ml cada
# Extraído: Atropina Solução Oftálmica 1% 5ml
# Extraído: Fentizol Óvulo 600mg 1 óvulo + 1 aplicador
# Extraído: Flogoral 3mg Pastilhas Sabor Menta 12un
# Extraído: Azukon MR 30mg 60 Comprimidos
# Extraído: Tarfic 0,03% Pomada Dermatológica 10g
# Extraído: Benalet Pastilhas Sabor Mel e Limão 12un
# Extraído: Neutrofer Fólico 150mg + 5mg 30 comprimidos revestidos
# Extraído: Bravan Duo 160mg/5mg 30 comprimidos
# Extraído: Ginkomed 80mg 30 comprimidos revestidos
# Extraído: DONAREN - 50mg, 60 comprimidos revestidos
# Extraído: Doril 6 comprimidos
# Extraído: Puran T4 150mcg 30 comprimidos
# Extraído: Level 0,10mg + 0,02mg 21 comprimidos revestidos
# Extraído: Repoflor 200mg 6 cápsulas duras
# Extraído: Omeprazol 20mg União Química 28 cápsulas duras
# Extraído: Nactali 75mcg 28 comprimidos revestidos
# Extraído: BetaTrinta 5mg/ml + 2 mg/ml Suspensão Injetável 1ml + seringa
# Extraído: Decongex Plus 4 comprimidos
# Extraído: Sal de Frutas Eno Abacaxi 2 envelopes com 5g cada
# Extraído: Cerazette 75mcg 84 comprimidos revestidos
# Extraído: Laxol Sabor Hortelã 60ml
# Extraído: Repoflor 250mg 6 envelopes
# Extraído: Diovan Amlo Fix 160mg + 5mg 28 comprimidos revestidos
# Extraído: Oxipelle 10mg/ml Solução Tópica 20ml
# Extraído: Tarfic 0,1% Pomada Dermatológica 30g
# Extraído: Isordil Sublingual 5mg 30 comprimidos sublinguais
# Extraído: Lisador 24 comprimidos
# Extraído: Sumax 50mg 2 comprimidos revestidos
# Extraído: Eparema Sabor Hortelã 12 flaconetes de 10ml cada
# Extraído: Leite de Magnésia Phillips Original 120ml
# Extraído: Synthroid 200mcg 30 comprimidos
# Extraído: Viagra 50mg 2 Comprimidos
# Extraído: Hixizine 2mg/ml Xarope 120ml
# Extraído: Resist 500mg 90 cápsulas
# Extraído: Antiácido Eno Pastilhas Mastigáveis 500mg Sabor Menta 8un
# Extraído: Ebatz 4mg 30 comprimidos revestidos
# Extraído: Sorox Sabor Fruras Vermelhas 550ml
# Extraído: Decongex Plus Gotas 20ml
# Extraído: Stezza 2,5mg + 1,5mg 28 comprimidos revestidos
# Extraído: Addera D3 10.000UI 10 cápsulas moles
# Extraído: Diprosalic 0,5mg/g + 30mg/g Pomada Dermatológica 30g
# Extraído: Fledoid 500 Gel 40g
# Extraído: Olmecor 40mg 30 comprimidos revestidos
# Extraído: Cranberry Herbamed 500mg 60 comprimidos
# Extraído: Malvona Solução Oral 100ml
# Extraído: Bravan Duo 320mg/5mg 30 comprimidos
# Extraído: Mega Mater Gestante 30 cápsulas
# Extraído: Iccor 5mg 30 comprimidos revestidos
# Extraído: Teste de Gravidez Gravtest Easy Cimed 1 Unidade
# Extraído: Magnazia Sabor Limão 240ml
# Extraído: Nevrix 100mg + 100mg + 5mg 90 comprimidos revestidos
# Extraído: Narix 0,5mg/ml Cimed 30ml
# Extraído: Varivax 100mg 30 comprimidos
# Extraído: Hormoskin Creme Dermatológico 15g
# Extraído: Inpruv DK 7.000UI + 100mcg Apsen, 8 Comprimidos
# Extraído: Oto-Xilodase Gotas 8ml
# Extraído: Icacort 1mg/g + 10mg/g Creme Dermatológico 30g
# Extraído: Moment 0,25mg/g Creme 50g
# Extraído: Strepsils Sabor Mel e Limão 24 pastilhas
# Extraído: Lactase 10.000 U.FCC Latolise 30 Cápsulas Neo Química
# Extraído: Ecasil 81 81mg 90 comprimidos revestidos
# Extraído: Trimbow 100/6/12,5 mcg 120 Doses
# Extraído: Glifage XR 1g 30 comprimidos de liberação prolongada
# Extraído: Novanlo 2,5mg 30 comprimidos
# Extraído: Fisioton 400mg 30 comprimidos revestidos
# Extraído: Indocid 50mg 30 cápsulas
# Extraído: Amome 50mcg Spray Nasal 120 acionamentos
# Extraído: Indapen SR 1,5mg 60 comprimidos revestidos
# Extraído: Gracial 25mcg + 40mcg +125mcg + 30mcg 22 comprimidos
# Extraído: Basaglar 100UI/ml 5 refis de 3ml
# Extraído: Estomazil Sabor Abacaxi 6 envelopes
# Extraído: Labirin 24mg 60 comprimidos
# Extraído: Rapilax 7,5mg/ml Gotas 30ml
# Extraído: Novalgina 50mg/ml Sabor Framboesa 100ml + seringa dosadora
# Extraído: Gynopac 4 comprimidos + Creme Ginecológico 35g + 7 aplicadores
# Extraído: Vick Pyrena Grip-7 5 Cápsulas
# Extraído: Spiriva Respimat 2,5mcg/dose 4ml + inalador Respimat (60 doses)
# Extraído: Xarope Vick 44E 240ml
# Extraído: Ancoron 200mg 60 comprimidos revestidos
# Extraído: Annita 20mg/ml, 1 frasco com 45ml de pó para suspensão de uso oral
# Extraído: Naprix 5mg 90 comprimidos
# Extraído: Bye Bye Fever para Bebês 0 a 2 Anos 2 unidades
# Extraído: Clenil A 400mcg/ml 10 flaconetes com 2ml cada
# Extraído: Neocopan Composto 20 comprimidos revestidos
# Extraído: Coristina D Pro 8 comprimidos
# Extraído: Vick Pyrena Grip-7 10 Cápsulas
# Extraído: Tandrilax Aché 15 comprimidos
# Extraído: Doril Enxaqueca 4 comprimidos revestidos
# Extraído: Antiácido Droxaine 240ml
# Extraído: Synthroid 88mcg 30 comprimidos
# Extraído: Alginac 1.000 30 comprimidos revestidos
# Extraído: Crevagin 30mg/g + 20mg/g Creme Ginecológico 40g + 7 aplicadores
# Extraído: Caltren 20mg 30 comprimidos
# Extraído: Addera D3 7.000UI 30 comprimidos revestidos
# Extraído: Rinosoro Jet 0,9% 100ml
# Extraído: Primosiston 2mg + 0,01mg 30 comprimidos
# Extraído: Vatis 150mg 90 comprimidos revestidos
# Extraído: Iziz 2,5mg + 1,5mg 84 Comprimidos Revestidos
# Extraído: Gaeso 20mg 28 comprimidos
# Extraído: Ultraproct LDO 1mg/g + 20mg/g Creme 30g + 1 cânula
# Extraído: Triplixam 10mg + 2,5mg + 10mg 30 comprimidos revestidos
# Extraído: Ad-Muc 100mg Pomada Bucal 10g
# Extraído: Spray Ciflogex Sabor Menta 30ml
# Extraído: Solução Oftálmica Ster 10mg/ml 5ml
# Extraído: Belara 2mg + 0,03mg 21 comprimidos revestidos
# Extraído: Nociclin 0,15mg + 0,03mg 21 comprimidos
# Extraído: Hidrali 45 Sabor Laranja 500ml
# Extraído: Dastene 0,5mg 30 cápsulas moles
# Extraído: Sais para Reidratação Oral Hidroral Sabor Tradicional 4 unidades de 27,9g cada
# Extraído: Cáscara Sagrada 75mg 45 Cápsulas Duras
# Extraído: Nevrix 100mg + 100mg + 5mg 60 comprimidos revestidos
# Extraído: Antiácido Simeco Plus Sabor Hortelã 240ml
# Extraído: Tarfic 0,1% Pomada Dermatológica 10g
# Extraído: Xarope Benetosse 15mg/ml Sabor Cereja 100ml
# Extraído: Vitamina D Sof D 50.000 UI 4 cápsulas gelatinosas moles
# Extraído: Pepsamar 230mg Sabor Menta 50 comprimidos mastigáveis
# Extraído: Dexilant 30mg Takeda 30 cápsulas de liberação retardada
# Extraído: Mylicon Antigases 75mg/ml Gotas 15ml
# Extraído: Kaloba 111,111mg 21 comprimidos revestidos
# Extraído: Myrafer 100mg 30 comprimidos revestidos
# Extraído: Iumi 3mg + 0,02mg 72 comprimidos revestidos
# Extraído: Olmecor 20mg 30 comprimidos revestidos
# Extraído: BENICAR HCT - 20 + 12,5mg, 30 comprimidos revestidos
# Extraído: Kóide D Xarope 120ml + copo medidor
# Extraído: Stanglit 30mg 60 comprimidos
# Extraído: Advil 600mg 12 Horas 2 comprimidos revestidos de liberação prolongada
# Extraído: Nausicalm B6 Sabor Cereja 20ml
# Extraído: Loratamed Loratadina 1mg/ml Sabor Uva 100ml
# Extraído: Creme Dermatológico Maleato de Dexclorfeniramina 10mg/g EMS 30g
# Extraído: Folagest Pré+ 400mcg 30 cápsulas moles
# Extraído: Naldecon Pack Dia e Noite 24 comprimidos
# Extraído: Tâmisa 20 75mcg + 20mcg 21 comprimidos revestidos
# Extraído: Ibupril 400mg 8 cápsulas gelatinosas moles
# Extraído: OsteoNutri 600mg + 400UI 60 comprimidos revestidos
# Extraído: Sal de Frutas Eno Guaraná 100g
# Extraído: Pedialyte Max Sabor Uva 500ml
# Extraído: Dorflex Uno 1g com 20 Comprimidos
# Extraído: Daflon 500mg FFPM 60 comprimidos revestidos
# Extraído: Neosaldina Dip 1g 10 comprimidos
# Extraído: Celestone Soluspan 3mg/ml + 3mg/ml 1 ampola com 1ml de solução de uso intramuscular
# Extraído: Engov After Sabor Citrus 250ml
# Extraído: Rinosoro SIC Spray 0,9% Descongestionante Nasal 50ml
# Extraído: Neosoro Infantil 30ml
# Extraído: Ultrafer 100mg 30 comprimidos revestidos
# Extraído: Benegrip 6 comprimidos revestidos
# Extraído: Loção Oleosa Dersani 200ml
# Extraído: Solução Oftálmica Azopt 10mg/ml 5ml
# Extraído: Mylanta Plus Sabor Menta 240ml
# Extraído: Broncho - Vaxom 7mg 30 cápsulas
# Extraído: Salonpas Pain Relief Patch 5 adesivos
# Extraído: Cataflam 50mg 20 drágeas
# Extraído: Decadron 4mg 10 comprimidos
# Extraído: Ogestan Pré 30 cápsulas
# Extraído: Neosaldina Dip 1g 20 comprimidos
# Extraído: Eparema Sabor Hortelã 200ml
# Extraído: Fluimucil 100mg/ml Solução Injetável 5 ampolas com 3ml cada
# Extraído: Magnopyrol 500mg/ml Gotas 20ml
# Extraído: Vaslip 10mg 30 comprimidos revestidos
# Extraído: Femina 150mcg + 20mcg 63 comprimidos revestidos
# Extraído: Diovan HCT 320mg + 25mg 28 comprimidos revestidos
# Extraído: Parasin 400mg Sabor Banan 1 comprimido mastigável
# Extraído: Noex 50mcg Spray Nasal 200 doses
# Extraído: Inpruv DK 50.000UI + 100mcg Apsen, 4 Comprimidos
# Extraído: Euthyrox 175mcg 50 comprimidos
# Extraído: Benegrip Multi Xarope Sabor Frutas Vermelhas 240ml
# Extraído: Sal de Frutas Eno Abacaxi 100g
# Extraído: Laxante L-Enema 130ml
# Extraído: Folifer 30 comprimidos revestidos
# Extraído: Flogoral 3mg Pastilhas Sabor Laranja 12un
# Extraído: Solução Oftálmica Ocupress 2% 5ml
# Extraído: Repoflor 100mg 12 cápsulas duras
# Extraído: Alektos 20mg 20 comprimidos
# Extraído: Maresis Baby 0,9% Spray Jato Suave Contínuo 100ml
# Extraído: Loxonin Flex 100mg 7 adesivos
# Extraído: Corus 25mg 30 comprimidos revestidos
# Extraído: Trayenta Duo 2,5mg + 850mg 60 comprimidos revestidos
# Extraído: Levoid 100mcg 30 comprimidos
# Extraído: Rehidrat 50 Sabor Natural 4 envelopes de 7,34g
# Extraído: Ésio 20mg 28 comprimidos revestidos
# Extraído: Noripurum Fólico 100mg + 0,35mg 30 comprimidos mastigáveis
# Extraído: Synthroid 137mcg 30 comprimidos
# Extraído: Trok 20mg/g + 0,64mg/g Creme Dermatológico 10g
# Extraído: Tropinal 20 comprimidos
# Extraído: Diclin 2mg + 0,035mg 63 comprimidos revestidos
# Extraído: Cueca para Hérnia Inguinal Dupla Dilepé Cor Preta Tamanho P
# Extraído: Synthroid 100mcg 30 comprimidos
# Extraído: Bexai 35mg 10 cápsulas duras
# Extraído: Pastilhas Benalet Sabor Menta 12un
# Extraído: Bravan Duo 160mg/10mg 30 comprimidos
# Extraído: Mounjaro Tirzepatida 2,5mg Solução Injetável 0,5ml + 4 Canetas Aplicadoras
# Extraído: Neutrofer Folato D 30 comprimidos revestidos
# Extraído: Hidralyte Sabor Água de Coco 500ml
# Extraído: Ibuflex 400mg Legrand 8 cápsulas gelatinosas moles
# Extraído: Kronel Gel Ginecológico 60g 10 aplicadores
# Extraído: Lacto-Purga 6 comprimidos revestidos
# Extraído: Fenergan 25mg 20 comprimidos revestidos
# Extraído: Allegra D 60mg + 120mg 10 comprimidos revestidos de camada dupla
# Extraído: Insulina novolin r refil 5X3,0ml
# Extraído: Buscofem Hot 2 adesivos térmicos descartáveis
# Extraído: Duphaston 10mg 28 comprimidos revestidos
# Extraído: Polaramine 2mg 20 comprimidos
# Extraído: Avide 100mg 9 cápsulas duras
# Extraído: Venzer 16mg 30 comprimidos
# Extraído: Xigduo XR 5mg + 1000mg 60 comprimidos revestidos de liberação prolongada
# Extraído: Ciflogex Pastilha Sabor Laranja 12un
# Extraído: Ibupril 300mg 20 comprimidos
# Extraído: Aerodine 100mcg Teuto Aerossol 200 doses + adaptador
# Extraído: Complexo Homeopático Almeida Prado N 06 60 Comprimidos
# Extraído: Celestrat 2mg + 0,25mg 20 comprimidos
# Extraído: Novanlo 5mg 90 comprimidos
# Extraído: Funchicórea Pó 3g
# Extraído: Omnic Ocas 0,4mg 60 comprimidos de liberação prolongada
# Extraído: Vastarel Caps LP 80mg 30 cápsulas duras de liberação prolongada
# Extraído: Colchis 0,5mg 30 comprimidos
# Extraído: Diovan HCT 320mg + 12,5mg 28 comprimidos revestidos
# Extraído: Condroflex 500mg + 400mg 60 cápsulas
# Extraído: Clexane 40mg/0,4ml 10 seringas preenchidas com 0,4ml com sistema de segurança
# Extraído: Norestin 0,35mg 35 comprimidos
# Extraído: Remilev 250mg + 60mg 20 comprimidos revestidos
# Extraído: Flavonid 450mg + 50mg 60 comprimidos revestidos
# Extraído: Anador 500mg 24 comprimidos
# Extraído: Flancox 400mg 10 comprimidos revestidos
# Extraído: Trayenta Duo 2,5mg / 1000mg 60 comprimidos revestidos
# ...
#   -> Aviso: Erro ao ler JSON-LD: Expecting ',' delimiter: line 1 column 248 (char 247)
# Extraído: Dermafree 15ml
# Extraído: Glicelivy Adulto Laxante 6 supositórios
# Extraído: HECLIVIR - 50mg/g, 1 bisnaga com 10g de creme de uso dermatológico
# Extraído: GINKOCAPS - 80mg, 30 cápsulas
# Extraído: LUTENIL - 5mg, 10 comprimidos
# Extraído: Pasta D'Água Mentolada 80g
#   -> Aviso: Erro ao ler JSON-LD: Expecting ',' delimiter: line 1 column 274 (char 273)
# Extraído: Ibuvix 400mg 10 comprimidos
# Extraído: IBUVIX - 600mg, 20 comprimidos revestidos
# Extraído: IBUVIX - 600mg, 30 comprimidos revestidos
# Extraído: PRESSEL - 10mg, 30 comprimidos
# Extraído: ENALAMED - 10mg, 30 comprimidos
# Extraído: VARICOSS - 15mg + 90mg, 20 drágeas
# Extraído: NIFEDIPRESS - 20mg, 30 comprimidos de liberação retardada
# Extraído: Bolt Caps 500mg + 400mg 30 cápsulas gelatinosas moles
# Extraído: Pergo 2mg/ml 120ml
# Extraído: Florent 200mg 6 cápsulas gelatinosas duras
# Extraído: SINVASTAMED - 40mg, 30 comprimidos revestidos
# Extraído: Solução Oral Nasaliv Sabor Cereja 60ml
# Extraído: Depura 50.000UI 4 cápsulas gelatinosas moles
# Extraído: Nienza 12,5mg 30 comprimidos
# Extraído: Probiótico Culturelle Junior 10 comprimidos mastigáveis com 0,623g
# Extraído: Nienza 6,25mg 30 comprimidos
# Extraído: Protopic 0,03% Pomada Dermatológica 10g
# Extraído: Nienza 3,125mg 30 comprimidos
# Extraído: Iverneo 6mg 2 comprimidos
# Extraído: Gripalcê Uno Bebê Sabor Cereja 15ml
# Extraído: Iverneo 6mg 4 comprimidos
# Extraído: Percoide 40mg 7 comprimidos
# Extraído: Soanza XR 35mg 30 comprimidos
# Extraído: EMS Pred 3mg/ml 60ml + seringa dosadora
# Extraído: Feldene 5mg/g Gel 30g
# Extraído: Tansudart 0,4mg 30 cápsulas duras de liberação prolongada
# Extraído: Polydrat 45 Sabor Guaraná 450ml
# Extraído: Itralex 100mg 4 Cápsulas Duras
# Extraído: Polydrat 45 Sabor Natural 450ml
# Extraído: Doricin Gotas 20ml
# Extraído: Neralgyn 20 drágeas
# Extraído: ONCICREM-A - 1,0mg/g, 1 bisnaga com 10g de pomada de uso bucal
# Extraído: Glicel 0,831g Laxante Lactante 6 supositórios
# Extraído: Digestil 4mg/ml Sabor Menta 20ml
# Extraído: Farlac 667mg/ml 1 frasco com 120mL de xarope
# Extraído: CICLOFEMME - 0,15mg + 0,03mg, 21 drágeas
# Extraído: Sinustrat 9,0mg/ml Infantil Solução Nasal 30ml
# Extraído: Espasmo Dimetiliv 80mg/ml + 2,5mg/ml Gotas 20ml
# Extraído: SINVAX - 40mg, 30 comprimidos revestidos
# Extraído: Elprazol 20mg 56 cápsulas duras de liberação retardada
# Extraído: Fledoid 300 Pomada 40g
# Extraído: Flomicin 200mg 4 envelopes de 1g cada
# Extraído: Fledoid 300 Gel 40g
# Extraído: Gynomax Creme Vaginal 35g + 7 aplicadores descartáveis
# Extraído: Flomicin 100mg 12 cápsulas
# Extraído: Ibufran 400mg 10 comprimidos
# Extraído: LORITIL - 10mg, 12 comprimidos
# Extraído: Reparil 10mg/g + 50mg/g Gel 100g
# Extraído: Pilem 0,75mg 2 comprimidos
#   -> Aviso: Erro ao ler JSON-LD: Expecting ',' delimiter: line 1 column 271 (char 270)
# Extraído: Hystin 2mg 20 comprimidos
# Extraído: Maleato de Dexclorfeniramina 2mg/5ml Medley 120ml
# Extraído: Solução Oftálmica Pilocarpina 4% 10ml
# Extraído: Resprin 12 comprimidos
# Extraído: Oceral 10mg/g Creme 20g
# Extraído: NEPRAZOL - 20mg, 28 cápsulas
# Extraído: Napronax 550mg 10 comprimidos revestidos
# Extraído: Ibufran 600mg 30 comprimidos
# Extraído: NASOCLEAN - 9mg/mL, 1 frasco com 100mL de solução de uso nasal
# Extraído: Diva 3mg + 0,03mg 21 comprimidos revestidos
# Extraído: Vannair 6/200mcg por inalação 120 doses 8ml
# Extraído: Nizoral 20mg/g Creme Dermatológico 30g
# Extraído: Diad 0,75mg 2 comprimidos
# Extraído: Magnesia de Phillips Tabs Sabor Morango 12 comprimidos mastigáveis
# Extraído: Aliviol Aerossol 120ml
# Extraído: Magnesia de Phillips Tabs Sabor Hortelã 12 comprimidos mastigáveis
# Extraído: Sinvastamed 20mg One Farma 30 comprimidos revestidos
# Extraído: Floratil Pack 250mg + 200mg 6 cápsulas
# Extraído: Flotac 70mg 14 cápsulas gelatinosas duras
# Extraído: Bisuisan Pó 50g
# Extraído: Leverctin - 6mg, 4 comprimidos
# Extraído: Fluimare HT 3% Solução Spray Nasal 50ml
# Extraído: Leverctin 6mg 2 comprimidos
# Extraído: FLUIMUCIL - 40mg/g, 16 envelopes com 5g de granulado de uso oral
# Extraído: FLUCANIL - 150mg, 2 cápsulas gelatinosas duras
# Extraído: Floratil Pack 250mg + 200mg 6 envelopes
# Extraído: Seretide Diskus 50mcg/500mcg 60 doses
# Extraído: Suplemento Alimentar Althaia Vitamina D3 7.000UI 4 cápsulas moles
# Extraído: Sal de Frutas Eno Sabor Camomila 100g
# Extraído: Listo 4mg 10 comprimidos de desintegração oral
# Extraído: Medvitd3 7.000UI Medley 8 cápsulas moles
# Extraído: Sonrisal Sabor Limão 10 comprimidos efervescentes
# Extraído: Renalapril 20mg 30 comprimidos
# Extraído: Spidufen770mg Sabor Damasco com 6 Envelopes de 3g cada
# Extraído: Gino-Canesten 3 Dias Creme Vaginal 20mg + 3 Aplicadores
# Extraído: Spidufen 770mg Sabor Damasco 20 Envelopes Com 3g
# Extraído: Lectrum 3,75mg 1 frasco-ampola dose única e 1 ampola de diluente
# Extraído: Renalapril 5mg 30 comprimidos
# Extraído: Pomada Dermatológica Nebacimed 15g
# Extraído: Dipimed 500mg/ml Gotas 20ml
# Extraído: Sinot 400mg/5ml 1 Frasco Com 100ml de Pó Para Suspensão de Uso Oral + 1 Seringa Dosadora
# Extraído: Ambrol Xarope Sabor Pêssego e Baunilha 100ml
# Extraído: Vitamina D Cimed 50.000UI 4 Cápsulas Moles
# Extraído: Selimax Pulso 500mg 9 comprimidos revestidos
# Extraído: Rifocina 10mg/ml 1 Frasco Spray Com 20ml de Solução de Uso dermatológico
# Extraído: Septam Bd 200mg/ml + 50mg/ml 1 Frasco Com 15G de Pó Para Suspensão de Uso Oral
# Extraído: Septam Bd 200mg/ml + 50mg/ml 1 Frasco Com 30G de Pó Para Suspensão de Uso Oral
# Extraído: VERSA - 60mg, 2 seringas preenchidas com 0,6mL de solução de uso subcutâneo ou intravenoso
# Extraído: Pletil 500mg 8 comprimidos revestidos
# Extraído: GAMMAR - comprimidos
# Extraído: FLORATIL PACK - 200mg/g + 250mg/1,25g, 6 sachês com 1g de pó de uso oral + 6 sachês com 1,25g de pó de uso oral
# Extraído: Clabat 500mg Caixa Contendo 14 comprimidos de Liberação Prolongada
# Extraído: Solly 10mg 30 comprimidos revestidos
# Extraído: Basaglar KwikPen 100UI/ml 5 canetas aplicadoras descartáveis com refis de 3ml
# Extraído: COVERSYL - 4mg, 30 comprimidos + sachês dessecante
# Extraído: Runner Eze 20mg + 10mg 60 comprimidos
# Extraído: Steaton Silimarina 200mg 30 cápsulas
# Extraído: ZYDENA - 100mg, 2 comprimidos revestidos
# Extraído: Florent 200mg 4 envelopes com 1g
# Extraído: Lipanon 250mg 30 cápsulas duras de liberação retardada
# Extraído: ZYDENA - 100mg, 1 comprimido revestido
# Extraído: Florent 100mg 12 cápsulas gelatinosas duras
# Extraído: LIORESAL - 10mg, 20 comprimidos
# Extraído: Vitamina D Sof D 2.000 UI 30 cápsulas gelatinosas moles
# Extraído: Tecnofer Sabor Laranja 30 comprimidos efervescentes
# Extraído: Suplemento Vitamínico Koli D3 Vit 7.000 UI 10 comprimidos revestidos
# Extraído: Targus Lat 40mg 10 adesivos transdérmicos
# Extraído: Suplemento Vitamínico Koli D3 Vit 50.000 UI 4 comprimidos revestidos
# Extraído: Alivium 400mg 20 cápsulas líquidas
# Extraído: CYMBALTA 60MG C/30 CPR
# Extraído: Imussuprex 50mg c/ 50 Comprimidos (Imunossupressores)
# Extraído: Sinot Clav 400mg + 57mg/5ml 1 Frasco Com 70ml de Pó Para Suspensão de Uso Oral + Seringa Dosadora
# Extraído: RIVOTRIL - 2mg, 20 comprimidos
# Extraído: Astro 600mg 1 Frasco de Pó Para Suspensão de Uso Oral + 1 Flaconete Com 9ml de Diluente + Seringa Dosadora
# Extraído: Maxitrol 1mg/ml + 5mg/ml + 6Mui/ml 1 Frasco Gotejador Com 5ml de Suspensão de Uso Oftalmológico
# Extraído: HETORI - 90mg, 14 comprimidos revestidos
# Extraído: PULMICORT - 0,25mg/mL, 20 frascos com 2mL de suspensão para nebulização
# Extraído: Lexapro 15mg 30 comprimidos
# Extraído: COQUES - 200mg, 30 cápsulas gelatinosas duras
# Extraído: Tempora 50mg 60 comprimidos revestidos
# Extraído: Kitapen 25mg c/ 30 Comprimidos (C1)
# Extraído: Mind 10mg Biolab Sanus 30 Comprimidos Revestidos
# Extraído: Vellana 50mg 30 comprimidos
# Extraído: Vensate LP 75mg Cristália 30 Cápsulas de Liberação Prolongada
# Extraído: Neupro 2mg/24h c/ 7 Adesivos (C1)
# Extraído: Vensate LP 150mg Cristália 30 Cápsulas de Liberação Prolongada
# Extraído: Primid 250mg 20 comprimidos
# Extraído: Escena 20mg 30 Comprimidos Revestidos C1
# Extraído: Remeron Soltab 45mg 30 comprimidos
# Extraído: Liberaflux 7,5mg/ml Sabor Cereja 100ml
# Extraído: HIDRAFIX 90 - 2,16mg/mL + 4,68mg/mL + 0,98mg/mL + 20,00mg/mL, 1 frasco com 250mL de solução de uso oral
# Extraído: LIARA - 3mg + 0,03mg, 21 comprimidos revestidos
# Extraído: Cef 500mg 10 Cápsulas
# Extraído: LIDY - 3mg + 0,02mg, 24 comprimidos revestidos
# Extraído: Motix FQM 50 Comprimidos
# Extraído: CYMBALTA 30MG C/30 CPR
# Extraído: HORMUS 250MG C/1 AMP 4ML
# Extraído: JUNEVE 50MG C/28 CPS GEL A3
# Extraído: Doss Colecalciferol 10.000 UI Com 4 cápsulas
# Extraído: Liberfem 2mg + 0,03mg 21 comprimidos revestidos
# Extraído: Colidis Gts 10ML
# Extraído: CELESTONE - 0,5mg, 20 comprimidos
# Extraído: Solução Oftálmica Toragesic Ofta 5mg/ml 5ml
# Extraído: Noctiden 10mg Com 30 Comprimidos
# Extraído: Quicard 35mg 60 Comprimidos Revestidos De Liberação Prolongada
# Extraído: Fostair DPI 200mcg + 6mcg 120 doses
# Extraído: Concárdio 5mg 30 comprimidos revestidos
# Extraído: LYRICA 75 MG C/28 CPS
#   -> Aviso: Erro ao ler JSON-LD: Expecting ',' delimiter: line 1 column 1405 (char 1404)
# Extraído: Succinato de Solifenacina 10mg Ranbaxy 30 comprimidos revestidos
# Extraído: VOEXTOR 10MG C/60 CPR REV C1
# Extraído: MENELAT 45 MG C/30 CPR
# Extraído: Tericin At 25mg + 125mg 1 Bisnaga Com 45G de Creme de Uso Ginecológico + 10 Aplicadores
# Extraído: Euthyrox 100mcg 50 comprimidos
# Extraído: Vynaxa 15mg 30 comprimidos revestidos
# Extraído: Vibral 30mg/ml Gotas 10ml
# Extraído: Ceclor 375mg/5ml 1 Frasco Com 100ml de Suspensão de Uso Oral + Seringa
# Extraído: Plurair 50mcg/dose Spray 60 doses 6ml
# Extraído: POLARAMINE EXPECTORANTE - 0,40mg/mL + 4mg/mL + 20mg/mL, 1 frasco com 120mL de solução de uso oral
# Extraído: Duspatalin 200mg 30 cápsulas gelatinosas duras de liberação prolongada
# Extraído: Polaramine 2,8mg/ml Gotas Sabor de Frutas 20ml
# Extraído: Crestor 40mg 30 comprimidos revestidos
# Extraído: DUPHASTON - 10mg, caixa contendo 14 comprimidos revestidos
# Extraído: Aerolin 4mg 20 comprimidos
# Extraído: POSPRAND - 2mg, 30 comprimidos
# Extraído: B-TABLOCK - 5mg/mL, 1 frasco gotejador com 5mL de solução de uso oftalmológico
# Extraído: Diamicron MR 60mg 60 comprimidos de liberação prolongada
# Extraído: Aerolin 2mg 20 comprimidos
# Extraído: Aerolin Nebules 2,5mg/2,5ml 20 flaconetes
# Extraído: Aerolin 0,4mg/ml 120 ml
# Extraído: Prós HP 2mg + 5mg 30 cápsulas gelatinosas duras
# Extraído: PREMARIN - 0,3mg, 28 drágeas
# Extraído: RILAN - 4%, 1 frasco spray com 13mL de solução de uso nasal
# Extraído: Profenid 25mg Gel 30g
# Extraído: RILAN - 2%, 1 frasco spray com 15mL de solução de uso nasal
# Extraído: Eliquis 2,5mg 20 comprimidos revestidos
# Extraído: EMSGrip 100mg/g Pó Sabor Mel e Limão 5g
# Extraído: Prelone 5mg 10 comprimidos
# Extraído: Ekson 200mg + 50mg 30 comprimidos
# Extraído: Profenid Protect 200mg + 20mg 10 cápsulas
# Extraído: Calcort 6mg 20 comprimidos
# Extraído: ROSULIB - 10mg, 30 comprimidos revestidos
# Extraído: Umckan 825mg/ml 50ml
# Extraído: Rusovas 5mg 60 comprimidos revestidos
# Extraído: Ritmonorm 300mg 60 comprimidos revestidos
# Extraído: Profenid 1mg/ml Xarope Pediátrico Sabor Tutti Frutti 150ml
# Extraído: Umckan 825mg/ml 20ml
# Extraído: Prazol 15mg 28 cápsulas de liberação retardada
# Extraído: UNIGYN - 1g, 2 comprimidos revestidos
# Extraído: Profenid 100mg 10 supositórios
# Extraído: Babydrax 4 sachês com Sais para Reidratação Oral
# Extraído: Baclofen 10mg 20 comprimidos
# Extraído: Untral 2,5mg 30 cápsulas duras
# Extraído: Bart H 300mg + 12,5mg 30 comprimidos
# Extraído: Brondelix 7mg/ml Xarope Sabor Cereja 100ml
# Extraído: Urovit 200mg 18 drágeas
# Extraído: Cuore 75mg 28 comprimidos revestidos
# Extraído: Urovit 100mg 25 drágeas
# Extraído: Betnovate 1mg/g Creme 15g
# Extraído: Vitamina D3 AltaD 1.000UI 30 comprimidos revestidos
# Extraído: Vitamina C Cenevit 2g Sabor Laranja 10 comprimidos efervescentes
# Extraído: Celestone 0,1mg/ml Elixir 120ml
# Extraído: Amaryl 3mg, 30 comprimidos
# Extraído: Betnovate 1mg/g Pomada 15g
# Extraído: Vitamina D3 AltaD 7.000UI 8 comprimidos revestidos
# Extraído: Solução Oftálmica Alphagan P 0,15% 5ml
# Extraído: BETES - 2mg, 30 comprimidos
# Extraído: Amaryl 2mg, 30 comprimidos
# Extraído: Amaryl 1mg, 30 comprimidos
# Extraído: Cardilol 6,25mg 30 comprimidos
# Extraído: Cardizem 30mg 50 comprimidos
# Extraído: Pantozol 20mg 28 Comprimidos revestidos de liberação retardada
# Extraído: Lanz 30mg 14 cápsulas duras de liberação retardada
# Extraído: Cardizem SR 120mg 20 cápsulas duras de liberação prolongada
# Extraído: Picbam 2,5mg 60 comprimidos revestidos
# Extraído: Lanz 30mg 28 cápsulas duras de liberação retardada
# Extraído: Cardizem 60mg 50 comprimidos
# Extraído: Picbam 5mg 20 comprimidos revestidos
# Extraído: Vasopril Plus 20mg + 12,5mg 60 comprimidos
# Extraído: Solução Oftálmica Patanol 1,11mg/ml 5ml
# Extraído: Salmeterol 25mcg + Fluticasona 50mcg 120 Doses Glenmark Genérico
# Extraído: VERSA - 80mg, 2 seringas preenchidas com 0,8mL de solução de uso subcutâneo ou intravenoso + sistema de segurança
# Extraído: Venocur Fit 263,2mg 60 comprimidos revestidos de liberação retardada
# Extraído: DAFORIN GTS C/20 ML
# Extraído: Aixa 2mg + 0,03mg 21 comprimidos revestidos
# Extraído: Alektos 20mg 15 comprimidos
#
# Extração concluída! Gerando tabela...
#               Marca           GTIN  Desconto  Preco com desconto  \
# 0     União Química  3662042000249     14.29              115.61
# 1            Nestlé  7891045031257      6.83               69.07
# 2             Apsen  7896637032247       NaN               59.90
# 3             Merck  7891721201806      4.30                7.65
# 4               Ems  7896004780511    213.19               29.07
# ...             ...            ...       ...                 ...
# 4271      Eurofarma  7891317487348       NaN                 NaN
# 4272         Abbott  7896255766135       NaN                 NaN
# 4273   Sigma Pharma  7894916201353       NaN                 NaN
# 4274         Medley  7896422531788       NaN                 NaN
# 4275         Hypera  7896641807763       NaN                 NaN
#
#                                                    link  \
# 0     https://www.drogariaveracruz.com.br/gel-para-h...
# 1     https://www.drogariaveracruz.com.br/suplemento...
# 2     https://www.drogariaveracruz.com.br/lactosil-f...
# 3     https://www.drogariaveracruz.com.br/glifage-xr...
# 4     https://www.drogariaveracruz.com.br/rivaroxaba...
# ...                                                 ...
# 4271  https://www.drogariaveracruz.com.br/versa-80mg...
# 4272  https://www.drogariaveracruz.com.br/venocur-fi...
# 4273  https://www.drogariaveracruz.com.br/daforin-gt...
# 4274  https://www.drogariaveracruz.com.br/aixa-2mg-0...
# 4275  https://www.drogariaveracruz.com.br/alektos-20...
#
#                                                    Nome  Desconto com pix  \
# 0                                         Blephagel 40g             20.07
# 1              Materna Nestlé 30 comprimidos revestidos             10.28
# 2                            Lactosil Flora 30 cápsulas               NaN
# 3     Glifage XR 500mg 30 comprimidos de liberação p...              4.68
# 4       Rivaroxabana 20mg EMS 30 comprimidos revestidos            214.64
# ...                                                 ...               ...
# 4271  VERSA - 80mg, 2 seringas preenchidas com 0,8mL...               NaN
# 4272  Venocur Fit 263,2mg 60 comprimidos revestidos ...               NaN
# 4273                                DAFORIN GTS C/20 ML               NaN
# 4274        Aixa 2mg + 0,03mg 21 comprimidos revestidos               NaN
# 4275                        Alektos 20mg 15 comprimidos               NaN
#
#       Preco pix  Preco unitario
# 0        109.83          129.90
# 1         65.62           75.90
# 2         56.91             NaN
# 3          7.27           11.95
# 4         27.62          242.26
# ...         ...             ...
# 4271        NaN             NaN
# 4272        NaN             NaN
# 4273        NaN             NaN
# 4274        NaN             NaN
# 4275        NaN             NaN
#
# [4276 rows x 9 columns]
